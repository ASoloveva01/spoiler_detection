# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.request import urlopen
pages = 40
for page in range(pages):
    page_url = f"https://www.livelib.ru/reviews/~{page}"
    reviews_page = urlopen(page_url)
    html_bytes = reviews_page.read()
    reviews_page = html_bytes.decode("utf-8")
    page_soup = BeautifulSoup(reviews_page,  "html.parser")
    review_urls = page_soup.find_all('a', {'class': 'footer-card__link'})
    for url in review_urls:
        review_page = urlopen("https://www.livelib.ru" + url['href'])
        html_bytes = review_page.read()
        review_page = html_bytes.decode("utf-8")
        review_soup = BeautifulSoup(review_page,  "html.parser")
        spoiler = review_soup.find('span', {'class': 'lenta-card__spoiler'})
        if spoiler:
            reviews_dict['is_spoiler'].append(0)
        else:
            reviews_dict['is_spoiler'].append(1)
        review = review_soup.find('div', {'id': 'lenta-card__text-review-full'})
        review_text = ' '.join([par.get_text() for par in review.find_all('p')])
        reviews_dict['review_text'].append(review_text)
    time.sleep(7)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN"
#     "http://www.w3.org/TR/html4/strict.dtd">
# <html>
#     <head>
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
#         <meta name="viewport" content="width=device-width,initial-scale=1"/>
#
#         <link rel="manifest" href="/pushmanifest.json">
#         <title id="title-head">Рецензии на книги — стр. 4</title>
#                     <meta name="description" content="Читайте рецензии на книги и узнайте, какие книги заслуживают вашего внимания. Пишите свои отзывы о книгах — делитесь впечатлениями!"></meta>
#                                     <meta name="robots" content="noindex, follow"></meta>
#                             <link rel="canonical" href="https://www.livelib.ru/reviews/~4">
#
#         <meta name="apple-itunes-app" content="app-id=905483030">
#         <meta name="google-play-app" content="app-id=ru.livelib.client">
#
#
#         <link rel="android-touch-icon" href="https://s.livelib.ru/img/android_phone_icon.png"/>
#
#         <link rel="icon" href="/favicon.ico"/>
#         <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png">
#
#
#
#
#
#         <link id="simplebar-css" href="https://s.livelib.ru/css/simplebar.20230531.css" rel="stylesheet">
#
#
#
#     <link rel="stylesheet" type="text/css" href="https://s.livelib.ru/css/style2017.20230531.css"/>
#     <link rel="stylesheet" type="text/css" href="https://s.livelib.ru/skins/ll2019/css/addbook2019.20230531.css"/>
#
#
#
#
#
#
#
#
#
#
#
#     <link rel="stylesheet" type="text/css" href="https://s.livelib.ru/skins/ll2019/css/style.20230531.css"/>
#
# <link rel="stylesheet" type="text/css" href="https://s.livelib.ru//css/authorize.20230531.css"/>
# <link rel="stylesheet" type="text/css" href="https://s.livelib.ru//css/authorize2019.20230531.css"/>
# <link rel="stylesheet" type="text/css" href="https://s.livelib.ru//css/booksmenu.20230531.css"/>
#
#     <link rel="stylesheet" type="text/css" href="https://s.livelib.ru//css/headerunreg.20230531.css"/>
#
#
#     <link href="https://s.livelib.ru/css/userbookform2020-v3.20230531.css" rel="stylesheet">
#
# <link rel="stylesheet" type="text/css" href="https://s.livelib.ru/skins/ll2019/css/header.20230531.css"/>
#
#
#
# <link rel="stylesheet" id="popup-share-style" type="text/css" href="https://s.livelib.ru/skins/ll2019/css/popup-share.20230531.css"/>
#
#
#
#         <!--[if IE 8]><style>#content img { max-width: none; }</style><![endif]-->
#
#
#                     <link rel="alternate" type="application/rss+xml" title="Рецензии на книги" href="/reviews/~rss">                                                                                                                        <link rel="prev" href="https://www.livelib.ru/reviews/~3"/>
#                                                     <link rel="next" href="https://www.livelib.ru/reviews/~5"/>
#
#
#
#
#                             <meta name="referrer" content="unsafe-url">
#
#
#
#
#
#
#
#
#
#
#
#
#                             <!-- start adfinity -->
#                 <link rel="stylesheet" href="https://cdn.adfinity.pro/foralls/adfinity.css">
#                 <!-- end adfinity -->
#
#
#             <link href="https://s.livelib.ru/css/authorize2019abtests.20230531.css" rel="stylesheet">
#
#
#                     </head>
#         <body id="body" class="reclist-data ">
#
# <input type="hidden" id="is_admin">
#
#
# <header class="page-header main-body ">
#
#                                         <div id="pageh" style="height:72px;display:none;"></div>
#
#                                                                                 <div class="prm-header"><div class="prm-block prm-block-17" id="prm-block-17" style=""></div></div>                                        <div id="fixed-menu-2019" class="page-header main-body">
#     <div class="page-header__wrapper">
#         <details class="site-nav ll-details-closed">
#     <summary class="site-nav__toggle" data-obj_id="1"></summary>
#     <div class="site-nav-background">
#         <ul class="site-nav__list" data-simplebar>
#             <li class="site-nav__item">
#             <details open>
#                 <summary><a href="/books">Что почитать</a></summary>
#                 <div>
#                     <a href="/books/novelties">Новинки</a>
#                     <a href="/rec/master">Рекомендации </a>
#                     <a href="/books/ratings">Рейтинги</a>
#                     <a href="/genres">Жанры</a>
#                     <a href="/authors">Авторы</a>
#                     <a href="/authors/blog/feed">Блоги авторов</a>
#                     <a href="/selections">Подборки</a>
#                     <a href="/awards">Премии</a>
#                     <a href="/publishers">Издательства</a>
#                     <a href="/characters">Персонажи</a>
#                 </div>
#             </details>
#             </li>
#             <li class="site-nav__item site-nav__item-discounts">
#                 <a href="/discounts">Скидки</a>
#             </li>
#             <li class="site-nav__item">
#                 <details open>
#                     <summary><a href="/feed">Лента</a></summary>
#                     <div>
#                         <a href="/reviews">Рецензии</a>
#                         <a href="/quotes">Цитаты</a>
#                         <a href="/stories">Истории</a>
#                         <a href="/lifehacks">Лайфхаки</a>
#                     </div>
#                 </details>
#             </li>
#
#             <li class="site-nav__item">
#                 <a href="/readers">Читатели</a>
#             </li>
#             <li class="site-nav__item">
#                 <a href="/groups">Группы</a>
#             </li>
#             <li class="user-nav__item"><a href="/challenge/2023">Книжный вызов 2023</a></li>
#             <li class="user-nav__item"><a href="/schoolchallenge">Школьный книжный вызов</a></li>
#             <li class="site-nav__item">
#                 <a href="/games">Игры и конкурсы</a>
#             </li>
#             <li class="site-nav__item"><a href="/groups/filter/category:0000001">Клубы</a></li>
#             <li class="site-nav__item">
#                 <a href="/afisha">Афиша</a>
#             </li>
#             <li class="site-nav__item">
#                 <a href="/tests">Тесты</a>
#             </li>
#             <li class="site-nav__item">
#                 <a href="/bookswap">Книгообмен</a>
#             </li>
#             <li class="site-nav__item">
#                 <a href="/giveaways/razdachi-knig">Раздачи</a>
#             </li>
#         </ul>
#     </div>
# </details>
#         <a class="page-header__logo" href="/">
# <img class="page-header__logo-image" src="https://s.livelib.ru/img/skins/ll2019/logo_ll.svg" width="114" height="23" alt="LiveLib">
# </a>
#
# <div class="page-header__search page-header__search-sa" id="header-top-search">
#     <form id="header-top-search-form" action="/find" autocomplete="on" method="POST">
#         <input class="ll-input-search" placeholder="Поиск книг" autocomplete="off" data-object_alias="booksauthors" data-result="search-res-block" id="find-text-ll2019" name="filter[search]" type="text" value="">
#         <a class="page-header__search-btn" href="javascript:void(0);"></a>
#             </form>
#     <div id="search-res-block"></div>
# </div>
#
#
#     <button type="submit" onclick="loginform_show(null,null,null,'register', null, 'headerauth');" class="page-header__login">Войти</button>
#
#         <div class="main-menu">
#     <div class="main-menu__limiter">
#     <ul class="main-menu__list">
#
#             <li class="main-menu__item"><a href="/">Главная</a></li>
#                             <li class="main-menu__item"><a href="/books">Что почитать</a></li>
#                             <li class="main-menu__item"><a href="/discounts">Скидки</a></li>
#                             <li class="main-menu__item"><a href="/genres">Жанры</a></li>
#                             <li class="main-menu__item"><a href="/authors">Авторы</a></li>
#                             <li class="main-menu__item main-menu__item--active"><a href="/reviews">Рецензии</a></li>
#                             <li class="main-menu__item"><a href="/quotes">Цитаты</a></li>
#                             <li class="main-menu__item"><a href="/selections">Подборки</a></li>
#                             <li class="main-menu__item"><a href="/lifehacks">Лайфхаки</a></li>
#                             <li class="main-menu__item"><a href="/groups">Группы</a></li>
#                             <li class="main-menu__item"><a href="/novelties/selection/20233-anonsy-knig-skoro-v-prodazhe">Новинки</a></li>
#                             <li class="main-menu__item"><a href="/publishers">Издательства</a></li>
#                             <li class="main-menu__item"><a href="/characters">Персонажи</a></li>
#                             <li class="main-menu__item"><a href="/readers">Читатели</a></li>
#                             <li class="main-menu__item"><a href="/stories">Истории</a></li>
#                             <li class="main-menu__item"><a href="/events">Мероприятия</a></li>
#                             <li class="main-menu__item"><a href="/giveaways">Раздачи</a></li>
#                             <li class="main-menu__item"><a href="/bookswap">Книгообмен</a></li>
#                             <li class="main-menu__item"><a href="/games">Игры</a></li>
#                             <li class="main-menu__item"><a href="/awards">Премии</a></li>
#                             <li class="main-menu__item"><a href="/tests">Тесты</a></li>
#                             <li class="main-menu__item"><a href="/challenge/2023">Книжный вызов 2023</a></li>
#                         </ul>
#     </div>
# </div>
#     </div>
# </div>
#             <input type="hidden" id="ll-new-header" value="ll2019">
#
#     </div>
#
#
#             <div id="tinyalert">
#                     </div>
#     </header>
#
# <main class="main-body page-content ">
#         <section class="header">
#
#
#
#
#
#
#
#
#
#
#
#
#
#             </section>
#                         <a id="top-anchor" name="top-anchor"></a>
#         <div id="message"></div>
#
#
#
#     <form id="userbook-form-div" class="section-form" action="/review/filter" method="post">
#         <div class="section-form__wrap">
#             <h1 class="section-form__title">Рецензии</h1>
#             <div class="section-form__search">
#                 <input type="search" name="filter[search]" id="section-form-search" placeholder="Искать" autofocus value="">
#                 <a class="section-form__search-btn" href="javascript:void(0);"></a>
#             </div>
#         </div>
#         <input type="checkbox" class="section-form__toggle" id="section-form__toggle"/>
#         <label for="section-form__toggle"></label>
#         <div class="section-form__inner">
#             <div class="section-form__select">
#                 <details class="ll-details-closed">
#                     <summary>
#                         Жанр
#                                             </summary>
#                     <div>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="0" data-value_holder="genre-input">Все</a>
#                                                                                     <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="535" data-value_holder="genre-input">Наука и образование</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1339" data-value_holder="genre-input">Гуманитарные и общественные науки</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="537" data-value_holder="genre-input">Гуманитарные и общественные науки</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="137" data-value_holder="genre-input">Детские книги</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="409" data-value_holder="genre-input">Зарубежная литература</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="387" data-value_holder="genre-input">Дом, семья, хобби и досуг</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1140" data-value_holder="genre-input">Публицистическая литература</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1" data-value_holder="genre-input">Бизнес-книги</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="612" data-value_holder="genre-input">Филология</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="780" data-value_holder="genre-input">Технические науки</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1284" data-value_holder="genre-input">Русская литература</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1282" data-value_holder="genre-input">Учебная литература</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="615" data-value_holder="genre-input">Языкознание</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1217" data-value_holder="genre-input">Современная проза</a>
#                                                                                                                 <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="510" data-value_holder="genre-input">Культура и искусство</a>
#
#                     </div>
#                 </details>
#                 <input type="hidden" id="genre-input" name="filter[genre_id]" value="">
#             </div>
#             <div class="section-form__select">
#                 <details class="ll-details-closed">
#                     <summary>
#                         Оценка                    </summary>
#                     <div>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="-1" data-value_holder="rating-input">Все</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="0" data-value_holder="rating-input">Без оценки</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="plus" data-value_holder="rating-input">Нравится</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="zero" data-value_holder="rating-input">Нормально</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="minus" data-value_holder="rating-input">Не нравится</a>
#                     </div>
#                 </details>
#                 <input type="hidden" id="rating-input" name="filter[rating]" value="-1">
#             </div>
#             <div class="section-form__select">
#                 <details class="ll-details-closed">
#                     <summary>
#                         Дата
#                                             </summary>
#                     <div>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="0" data-value_holder="month-input">Все</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="1" data-value_holder="month-input">Месяц</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="3" data-value_holder="month-input">3 месяца</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="6" data-value_holder="month-input">Полгода</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="12" data-value_holder="month-input">Год</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="24" data-value_holder="month-input">2 года</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="36" data-value_holder="month-input">3 года</a>
#                     </div>
#                 </details>
#                 <input type="hidden" id="month-input" name="filter[months]" value="">
#             </div>
#             <div class="section-form__select">
#                 <details class="ll-details-closed">
#                     <summary>
#                         По дате добавления
#                                             </summary>
#                     <div>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="when" data-value_holder="reviews-filter-order">По дате добавления</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="bookrating" data-value_holder="reviews-filter-order">По рейтингу книги</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="plus" data-value_holder="reviews-filter-order">Самые популярные</a>
#                         <a href="javascript:void(0);" onclick="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="discussed" data-value_holder="reviews-filter-order">Самые обсуждаемые</a>
#                                             </div>
#                 </details>
#                                     <input type="hidden" id="reviews-filter-order" name="filter[order]" value="when
#                     ">
#                             </div>
#
#                                                             </div>
#         <input type="hidden" name="filter[page]" value="reviews">
#         <input type="hidden" name="filter[user_login]" id="user_login-input" value="">
#     </form>
#     <div class="section-menu">
#         <div class="section-menu__limiter">
#             <ul class="section-menu__list">
#                 <li class="section-menu__item section-menu__item--active"><a href="/reviews">Рецензии на книги</a></li>
#                                 <li class="section-menu__item"><a href="/reviews/experts">Рецензии экспертов</a></li>
#                 <li class="section-menu__item"><a href="/reviews/frommain">Рецензии с главной</a></li>
#                 <li class="section-menu__item"><a href="/reviews/only">Единственные</a></li>
#                                 <li class="section-menu__item"><a href="/media/reviews">Рецензии критиков</a></li>
#                             </ul>
#         </div>
#     </div>
#
# <div class="lenta__wrapper">
#     <div class="lenta__limiter">
#                     <input type="radio" id="lenta-group-1" name="lenta-group" checked="">
#             <label for="lenta-group-1" class="lenta-group__title">Топ пользователей</label>
#
#             <div class="lenta-user__list">
#                                     <input type="checkbox" id="lenta-user-ParatScorner" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="ParatScorner" data-value_holder="user_login-input">
#                     <label for="lenta-user-ParatScorner" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/ParatScorner/40x40/d73f/ParatScorner.jpg" alt="ParatScorner" width="100%" height="100%">
#                         <p class="lenta-user__name">ParatScorner</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-Chatterelle" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="Chatterelle" data-value_holder="user_login-input">
#                     <label for="lenta-user-Chatterelle" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/Chatterelle/40x40/b375/Chatterelle.jpg" alt="Chatterelle" width="100%" height="100%">
#                         <p class="lenta-user__name">Chatterelle</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-FredBah" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="FredBah" data-value_holder="user_login-input">
#                     <label for="lenta-user-FredBah" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/FredBah/40x40/b072/FredBah.jpg" alt="FredBah" width="100%" height="100%">
#                         <p class="lenta-user__name">FredBah</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-Mari_Kost" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="Mari_Kost" data-value_holder="user_login-input">
#                     <label for="lenta-user-Mari_Kost" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/Mari_Kost/40x40/0fae/Mari_Kost.jpg" alt="Mari_Kost" width="100%" height="100%">
#                         <p class="lenta-user__name">Mari_Kost</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-love_my__man" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="love_my__man" data-value_holder="user_login-input">
#                     <label for="lenta-user-love_my__man" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/love_my__man/40x40/261f/love_my__man.jpg" alt="love_my__man" width="100%" height="100%">
#                         <p class="lenta-user__name">love_my__man</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-anispersik" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="anispersik" data-value_holder="user_login-input">
#                     <label for="lenta-user-anispersik" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/anispersik/40x40/a3cf/anispersik.jpg" alt="anispersik" width="100%" height="100%">
#                         <p class="lenta-user__name">anispersik</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-timeladyrose" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="timeladyrose" data-value_holder="user_login-input">
#                     <label for="lenta-user-timeladyrose" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/timeladyrose/40x40/036b/timeladyrose.jpg" alt="timeladyrose" width="100%" height="100%">
#                         <p class="lenta-user__name">timeladyrose</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-InnaMis" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="InnaMis" data-value_holder="user_login-input">
#                     <label for="lenta-user-InnaMis" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/InnaMis/40x40/5b97/InnaMis.jpg" alt="InnaMis" width="100%" height="100%">
#                         <p class="lenta-user__name">InnaMis</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-CoBeHoK" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="CoBeHoK" data-value_holder="user_login-input">
#                     <label for="lenta-user-CoBeHoK" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/CoBeHoK/40x40/f33a/CoBeHoK.jpg" alt="CoBeHoK" width="100%" height="100%">
#                         <p class="lenta-user__name">CoBeHoK</p>
#                     </label>
#                                     <input type="checkbox" id="lenta-user-OlgaRajhel" onchange="set_form_hidden_value($(this));" data-form_submit="userbook-form-div" data-value="OlgaRajhel" data-value_holder="user_login-input">
#                     <label for="lenta-user-OlgaRajhel" class="lenta-user__item">
#                         <img class="lenta-user__avatar" src="https://i.livelib.ru/userpic/OlgaRajhel/40x40/ef11/OlgaRajhel.jpg" alt="OlgaRajhel" width="100%" height="100%">
#                         <p class="lenta-user__name">OlgaRajhel</p>
#                     </label>
#                             </div>
#
#     </div>
# </div>
#
# <section class="lenta__content">
#
#
#                 <div class="lenta__list" id="book-reviews">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <article class="review-card lenta__item ">
#     <meta itemprop="identifier" content="3461860">
#
#
#
#
#
#         <div class="header-card">
#                     <a class="header-card-user" href="/reader/AleksandraKravetz">
#                 <img data-pagespeed-no-defer class="header-card-user__avatar" width="100%" height="100%" src="https://i.livelib.ru/userpic/AleksandraKravetz/40x40/b92e/Kravets_Aleksandra.jpg" width="100%" height="100%" alt="Кравец Александра (AleksandraKravetz)">
#             </a>
#                                                             <a class="header-card-user__name" href="/reader/AleksandraKravetz" title="Кравец Александра (AleksandraKravetz)">
#                         <span>Кравец Александра</span>
#                     </a>
#                                                                                     <a class="header-card__category" href="/reviews">
#                                     написала рецензию
#                                 </a>
#
#
#
#
#
#
#                 <div class="header-card__menu">
#             <div class="header-card__menu-block">
#
#
#
#
#
#
#                                                                             <a href="javascript:void(0)" onclick="return ll_get_claim_form(event, 'review', 3461860);" title="Пожаловаться">Пожаловаться</a>
#
#
#
#
#                             </div>
#         </div>
#                 </div>
#         <div class="lenta-card">
#
#
#
#     <div class="lenta-card-book">
#                         <img data-pagespeed-no-defer class="lenta-card-book__bg" src="https://s1.livelib.ru/boocover/1003003803/200/9688/Olga_Miklashevskaya__Zmei._Gnev_Bozhij.jpg" width="100%" height="auto" alt="Ольга Миклашевская - Змеи. Гнев Божий">
#         <a class="lenta-card-book__link" href="/book/1003003803-zmei-gnev-bozhij-olga-miklashevskaya">
#             <img data-pagespeed-no-defer class="lenta-card-book__img" src="https://s1.livelib.ru/boocover/1003003803/200/9688/Olga_Miklashevskaya__Zmei._Gnev_Bozhij.jpg" width="100%" height="100%" alt="Ольга Миклашевская - Змеи. Гнев Божий">
#         </a>
#                     <div class="lenta-card-book__wrapper">
#                 <a class="lenta-card__book-title" href="/book/1003003803-zmei-gnev-bozhij-olga-miklashevskaya">Змеи. Гнев Божий</a>
#                 <p class="lenta-card__author-wrap">
#                                                                                                                                 <a class="lenta-card__author" href="/author/533171-olga-miklashevskaya">Ольга Миклашевская</a>
#
#                 </p>
#                                     <div class="lenta-card__rating">
#
#
#     <span>3,4</span>
#                     </div>
#
#
#             <div data-view_mode="plus" data-userbook_id="0" data-strict_edition_id="0" data-rand_id="567668" data-show_extended="" data-show="" data-edition_id="1003003803" class="userbook-container   ub-edition-1003003803 ub-book-2452351 btn-add-plus__wrapper ub-container" data-asource="review" data-design="ll2019" id="xa-main-1003003803-0-567668">
#
#                 <a href="javascript:void(0);" onclick="ub_form2020(1003003803, 0, 0, 567668, event);" class="btn-add-plus"><i></i></a>
#                 <input type="hidden" id="ub-viewmode-1003003803" value="btn-add-plus">
#
#     </div>
#
#                                 </div>
#             </div>
#                             <div class="lenta-card__details">
#
#             <p class="lenta-card__date">6&nbsp;июня&nbsp;2023&nbsp;г. 13:35</p>
#
#
#
#             <p class="lenta-card__aliases">
#                 <span>17</span>
#             </p>
#         </div>
#                     <h3 class="lenta-card__title">
#                                     <span class="lenta-card__mymark">
#
#
#
#                         4
#                     </span>
#
#
#                                                                                 <a href="/review/3461860-zmei-gnev-bozhij-olga-miklashevskaya">Если ад где-то и есть, то он на Земле</a>            </h3>
#
#
#
#                     <div id="lenta-card__text-review-3461860-wrapper-5086482" class="lenta-card__text without-readmore" data-object_alias="review" data-object_id="3461860">
#                                     <div id="lenta-card__text-review-escaped">
#                         <p><p>Ничего я не ждала от этой книги. Взяла, лишь из-за низкой цены и цепляющего названия <b>"Змеи. Гнев Божий"</b>. И по началу чтения моё отношение скатывалось от нейтрального к отрицательному. Особенно выбивали моменты из разряда <i>"Они пили "Балтику" сидя во дворе"</i>. Было даже желание закрыть книгу, но я дала ей шанс и..<b>не пожалела!</b></p><p><u>Плюсы книги:</u></p><p><b>+ </b>Динамичный сюжет</p><p><b>+ </b>Повествование ведётся в нескольких временных линиях, сюжет собирается как пазл. Мне такое по душе!</p><p><b>+ </b>Мифология! Это всегда интересно при яркой подаче. Но не воспринимайте сюжет за истинный пересказ мифов, это лишь фантазия автора <i>(как она сама и напоминает перед и после основного текста).</i></p><p><b>+ </b>Персонажи и их раскрытие. Моё мнение о каждом персонаже менялось на протяжении всей книги! Сложно было понять - на кого вешать ярлык "хороший", на кого…</p></p>
#                                             </div>
#                                             <a href="javascript:void(0);" class="read-more__link" data-rand_id="5086482" data-object_alias="review" data-object_id="3461860" data-object_text_action="expand" onclick="feed_object_text_show_link_process($(this));">Развернуть</a>
#                                                 </div>
#
#     </div>
#
#
#
#
#
#
#
#
#
#                                     <div class="review-card__footer footer-card">
#             <div class="footer-card__soc-active sab">
#                                 <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461860' data-type='vote' data-design='ll2019'>
#                     <a class="sab__link popup-load-data icon-like" data-vote_state_class="sab__link--active" id="vote-plus-hand-review-3461860" href="javascript:void(0);" onclick="return ll_vote('review', 3461860, 1, 2,'','');" title="Мне нравится">
#                         <span id="vote-plus-span-review-3461860">2</span>
#                     </a>
#                 </div>
#                                                     <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461860' data-type='comment' data-design='ll2019'>
#                         <a class="sab__link icon-comment" href="/review/3461860-zmei-gnev-bozhij-olga-miklashevskaya#comments" title="Комментарии" onmousedown="sa_send_click('review', '3461860', 'comment');">
#                             <span>0</span>
#                         </a>
#                     </div>
#
#                 <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461860' data-type='favorite' data-design='ll2019'>
#                     <span id="fav-review-3461860">
#                                         <a id="a-fav-review-3461860" class="sab__link icon-bookmark" href="javascript:void(0);" onclick="ll_fav('review', 3461860, 1, 0, '', '', 'll2019');" title="Добавить в избранное">
#                             <span class="count-in-fav">0</span>
#                     </a>
#
#                     </span>
#                 </div>
#
#
#             </div>
#
#
#
#
#                             <div class="sab__wrapper soc-active-block__wrapper" onclick="ll_get_socials_networks_popup('review', '3461860', '','', '','content-popup')">
#     <a class="sab__link icon-share" href="javascript:void(0);">
#         <span style="" id="count-share-review-3461860">0</span>
#     </a>
#     </div>
#
#                             <a class="footer-card__link" href="/review/3461860-zmei-gnev-bozhij-olga-miklashevskaya" title="Перейти к рецензии"></a>
#
#         </div>
#                 <img src='/service/visitlist/review.3461860' style="height:0; display:block">
#                         </article>
#
#
#
#
#
#
#
#
#
#
#
#
#                 <article class="review-card lenta__item ">
#     <meta itemprop="identifier" content="3461857">
#
#
#
#
#
#         <div class="header-card">
#                     <a class="header-card-user" href="/reader/NIKA__1958?es=3461857">
#                 <img data-pagespeed-no-defer class="header-card-user__avatar" width="100%" height="100%" src="https://i.livelib.ru/userpic/NIKA__1958/40x40/5418/NIKA__1958.jpg" width="100%" height="100%" alt="NIKA__1958">
#             </a>
#                                         <div class="header-card__wrapper">
#                     <div class="header-card__row1">
#                         <a class="header-card-user__name" href="/reader/NIKA__1958?es=3461857" title="NIKA__1958">
#                              <span>NIKA__1958</span></a>
#                         <a class="header-card__category" href="/reviews">написала рецензию</a>
#                     </div>
#                     <div class="header-card__row2">
#                         <p class="header-card-user__class">Эксперт</p>
#                         <p class="header-card-user__status"></p>
#                     </div>
#                 </div>
#
#
#
#
#                 <div class="header-card__menu">
#             <div class="header-card__menu-block">
#
#
#
#
#
#
#                                                                             <a href="javascript:void(0)" onclick="return ll_get_claim_form(event, 'review', 3461857);" title="Пожаловаться">Пожаловаться</a>
#
#
#
#
#                             </div>
#         </div>
#                 </div>
#         <div class="lenta-card">
#
#
#
#     <div class="lenta-card-book">
#                         <img data-pagespeed-no-defer class="lenta-card-book__bg" src="https://s1.livelib.ru/boocover/1008216412/200/298d/Antonina_Krejn__Ulybnis_mne_Artur_Edinbrog.jpg" width="100%" height="auto" alt="Антонина Крейн - Улыбнись мне, Артур Эдинброг">
#         <a class="lenta-card-book__link" href="/book/1008216412-ulybnis-mne-artur-edinbrog-antonina-krejn?es=3461857">
#             <img data-pagespeed-no-defer class="lenta-card-book__img" src="https://s1.livelib.ru/boocover/1008216412/200/298d/Antonina_Krejn__Ulybnis_mne_Artur_Edinbrog.jpg" width="100%" height="100%" alt="Антонина Крейн - Улыбнись мне, Артур Эдинброг">
#         </a>
#                     <div class="lenta-card-book__wrapper">
#                 <a class="lenta-card__book-title" href="/book/1008216412-ulybnis-mne-artur-edinbrog-antonina-krejn?es=3461857">Улыбнись мне, Артур Эдинброг</a>
#                 <p class="lenta-card__author-wrap">
#                                                                                                                                                                                             <a class="lenta-card__author" href="/author/1180506?es=3461857-antonina-krejn">Антонина Крейн</a>
#
#                 </p>
#                                     <div class="lenta-card__rating">
#
#
#     <span>4,1</span>
#                     </div>
#
#
#             <div data-view_mode="plus" data-userbook_id="0" data-strict_edition_id="0" data-rand_id="889452" data-show_extended="" data-show="" data-edition_id="1008216412" class="userbook-container   ub-edition-1008216412 ub-book-5841793 btn-add-plus__wrapper ub-container" data-asource="review" data-design="ll2019" id="xa-main-1008216412-0-889452">
#
#                 <a href="javascript:void(0);" onclick="ub_form2020(1008216412, 0, 0, 889452, event);" class="btn-add-plus"><i></i></a>
#                 <input type="hidden" id="ub-viewmode-1008216412" value="btn-add-plus">
#
#     </div>
#
#                                 </div>
#             </div>
#                             <div class="lenta-card__details">
#
#             <p class="lenta-card__date">6&nbsp;июня&nbsp;2023&nbsp;г. 13:32</p>
#
#
#
#             <p class="lenta-card__aliases">
#                 <span>15</span>
#             </p>
#         </div>
#                     <h3 class="lenta-card__title">
#                                     <span class="lenta-card__mymark">
#
#
#
#                         4.5
#                     </span>
#
#
#                                                                                 <a href="/review/3461857-ulybnis-mne-artur-edinbrog-antonina-krejn">Артур Эдинброг мне улыбнулся</a>            </h3>
#
#
#
#                     <div id="lenta-card__text-review-3461857-wrapper-8390631" class="lenta-card__text without-readmore" data-object_alias="review" data-object_id="3461857">
#                                     <div id="lenta-card__text-review-escaped">
#                         <p><p>Итак, с чего началась эта волшебная история. С того, что искусствоведа Вилку-Виолетту затянул в портал вместо её кота Уорхола. Попала она в магический университет Форван в качестве фамильяра к студенту-выпускнику Артуру (ударение на букву "А") Эдинброгу. Думаете, такое невозможно, но, как оказалось, случается. Должен быть тот кот в качестве тигра, но попала Вилка.</p><p>Уж попала, так попала. По полной программе. И спать ей пришлось в вольере, но хорошо хоть кроватью обеспечили и постельным бельём, а не подстилкой. Тигра ведь ждали. Ага, потому что кот тот стал превращаться в тигра под действием магии, и Виолетта кинулась его спасать, вот и попала.</p><p>А дльше начались приключения девушки-фамильяра-искусствоведа в мире магии. Давно уже хорошее и качественное фэнтези не вызывало у меня таких…</p></p>
#                                             </div>
#                                             <a href="javascript:void(0);" class="read-more__link" data-rand_id="8390631" data-object_alias="review" data-object_id="3461857" data-object_text_action="expand" onclick="feed_object_text_show_link_process($(this));">Развернуть</a>
#                                                 </div>
#
#     </div>
#
#
#
#
#
#
#
#
#
#                                     <div class="review-card__footer footer-card">
#             <div class="footer-card__soc-active sab">
#                                 <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461857' data-type='vote' data-design='ll2019'>
#                     <a class="sab__link popup-load-data icon-like" data-vote_state_class="sab__link--active" id="vote-plus-hand-review-3461857" href="javascript:void(0);" onclick="return ll_vote('review', 3461857, 1, 5,'','');" title="Мне нравится">
#                         <span id="vote-plus-span-review-3461857">5</span>
#                     </a>
#                 </div>
#                                                     <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461857' data-type='comment' data-design='ll2019'>
#                         <a class="sab__link icon-comment" href="/review/3461857-ulybnis-mne-artur-edinbrog-antonina-krejn#comments" title="Комментарии" onmousedown="sa_send_click('review', '3461857', 'comment');">
#                             <span>0</span>
#                         </a>
#                     </div>
#
#                 <div class="sab__wrapper popup-load-data" data-object_alias='review' data-object_id='3461857' data-type='favorite' data-design='ll2019'>
#                     <span id="fav-review-3461857">
#                                         <a id="a-fav-review-3461857" class="sab__link icon-bookmark" href="javascript:void(0);" onclick="ll_fav('review', 3461857, 1, 0, '', '', 'll2019');" title="Добавить в избранное">
#                             <span class="count-in-fav">0</span>
#                     </a>
#
#                     </span>
#                 </div>
#
#
#             </div>
#
#
#
#
#                             <div class="sab__wrapper soc-active-block__wrapper" onclick="ll_get_socials_networks_popup('review', '3461857', '','', '','content-popup')">
#     <a class="sab__link icon-share" href="javascript:void(0);">
#         <span style="" id="count-share-review-3461857">0</span>
#     </a>
#     </div>
#
#                             <a class="footer-card__link" href="/review/3461857-ulybnis-mne-artur-edinbrog-antonina-krejn" title="Перейти к рецензии"></a>
#
#         </div>
#                 <img src='/service/visitlist/review.3461857' style="height:0; display:block">
#                         </article>
#
#
#
#
#
#
#
#
#
#
# <article class="review-card lenta__item ">
#     <meta itemprop="identifier" content="3461854">
#
#
#
#
#
#         <div class="header-card">
# ...
#         </symbol>
#         <symbol id="icon-book-exchange" viewBox="0 0 26 32">
#             <path fill-rule="evenodd" clip-rule="evenodd" d="M5.33327 26.6667H2.66667C1.14583 26.6667 -4.51997e-06 25.5 0 24V2.66667C0 1.14583 1.125 0 2.66667 0H5.33327H17.3333H17.3333C18.8958 0 20 1.13542 20 2.66667V5.3334H22.6666C23.5654 5.3334 24.3125 5.7091 24.7851 6.31972C25.1341 6.77065 25.3334 7.34974 25.3334 8.00028V29.3336C25.3334 30.818 24.2292 32.0003 22.6667 32.0003H8.00007C6.47924 32.0003 5.3334 30.8336 5.3334 29.3336V26.6667H5.33327ZM6.66674 26.6667V29.3336C6.66674 30.0003 7.3334 30.667 8.00007 30.667H8.33947C8.12203 30.2773 7.99991 29.8231 7.99991 29.3334V26.6667H6.66674ZM9.33324 26.6667V29.3334C9.33324 30.0001 9.99991 30.6667 10.6666 30.6667H22.6666C23.3333 30.6667 23.9999 30.0001 23.9999 29.3334V8.00007C23.9999 7.75007 23.9062 7.50007 23.7538 7.28522C23.7284 7.24942 23.7014 7.21459 23.6729 7.1809C23.4166 6.87778 23.0417 6.66694 22.6667 6.66694H20V24C20 25.2761 19.184 26.329 17.9622 26.5993C17.7628 26.6434 17.5526 26.6667 17.3333 26.6667H17.3333H9.33324ZM1.33333 2.66667V24C1.33333 24.6667 2 25.3333 2.66667 25.3333H3.00604C2.78868 24.9437 2.6666 24.4896 2.6666 24V2.66667C2.6666 2.17417 2.78458 1.721 2.99648 1.33333H2.66667C2 1
#         </symbol>
#         <symbol id="icon-mybook" viewBox="0 0 16 16">
#             <path fill-rule="evenodd" clip-rule="evenodd" d="M2.18511 15.7103C0.979778 15.5836 0.000333333 14.5503 0 13.4066V2.59328C0.000333333 1.44983 0.979778 0.416389 2.18333 0.289945C6.05096 -0.0965741 9.94747 -0.0966485 13.8151 0.289723C15.0202 0.416278 15.9996 1.44972 16 2.59317V13.4065C15.9997 14.5503 15.0202 15.5836 13.8167 15.7102C11.8838 15.9034 9.9425 16.0001 8 15.9999C6.05809 16.0001 4.11739 15.9034 2.18511 15.7103Z" fill="url(#paint0_linear)"/>
#             <path d="M9.17567 8.73611C9.33522 8.56811 9.64678 8.591 9.78233 8.73611C9.91789 8.88122 9.96844 9.11611 9.78233 9.38056L8.505 10.7941V12.5004C8.505 12.7856 8.28967 13.0004 8.00011 13.0004C7.71033 13.0004 7.499 12.7857 7.499 12.5004V10.7942L6.21367 9.43767C6.04233 9.183 6.07178 8.953 6.21367 8.784C6.35556 8.61489 6.64722 8.60389 6.78156 8.73611C6.916 8.86833 7.96711 9.97656 8.00011 10.0038C8.03267 9.97489 9.08111 8.83578 9.17567 8.73611ZM10.9944 4C11.2609 4 11.5 4.24667 11.5 4.51133V11.0084C11.5 11.2703 11.2753 11.5122 10.9944 11.5122C10.7138 11.5122 10.5114 11.2702 10.5114 11.0084V5.73289L8.47922 8.12911C8.18189 8.421 7.835 8.42644 7.50156 8.12911L5.49822 5.73278V11.0083C5.49822 11.275 5.28367 11.5122 5.003 11.5122C4.72278 11.5122 4.5 11.2749 4.5 11.0084V4.46311C4.5 4.20122 4.73078 4 5.003 4C5.22644 4 5.36389 4.08367 5.49822 4.29244L8 7.214L10.5114 4.29244C10.6489 4.09556 10.7828 4 10.9944 4Z" fill="#BE5B04"/>
#             <defs>
#                 <linearGradient id="paint0_linear" x1="8" y1="0" x2="8" y2="15.9999" gradientUnits="userSpaceOnUse">
#                     <stop stop-color="#FAD961"/>
#                     <stop offset="1" stop-color="#FB9E4A"/>
#                 </linearGradient>
#             </defs>
#         </symbol>
#         <symbol id="icon-chitaigorod" viewBox="0 0 16 16">
#             <path d="M0 0H6L4 16H0V0Z" fill="#26A9E0"/><path d="M8 0H10L11 16H6L8 0Z" fill="#26A9E0"/><path d="M16 0H13L14 16H16V0Z" fill="#26A9E0"/>
#         </symbol>
#         <symbol id="icon-labirint" viewBox="0 0 16 16">
#             <path fill-rule="evenodd" clip-rule="evenodd" d="M0 0V16H16V0H0ZM12.2 6.5V13H9.5V6.7L5 13H2L9.2 3H12.2L9.8 6.5H12.2Z" fill="black"/>
#         </symbol>
#     </svg>
# </div>
#
# <script type="text/javascript">var img = document.createElement("img");img.setAttribute("style", "position:fixed; left:-999px;");img.setAttribute("data-pagespeed-no-defer","");img.src = "/service/spv?v=d&r="+encodeURIComponent(document.referrer)+"&d=" + Math.floor(Math.random() * 1000000);document.body.appendChild(img);</script>
# </body>
# </html>
# -------------------------------------------------

# %%
import pandas as pd
reviews_df = pd.DataFrame.from_dict(reviews_dict)
reviews_df.to_csv("reviews.csv")
